# %%
# Part 1: Import necessary libraries
import os
import pandas as pd
import numpy as np
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
# Part 2: Load and preprocess the data
def load_data(train_dir, train_csv):
    # Read the CSV file
    data = pd.read_csv(train_csv)
    data['path'] = train_dir + data['ID']  # Add full path to images
    
    # Encode labels (YOUNG, MIDDLE, OLD)
    label_encoder = LabelEncoder()
    data['label'] = label_encoder.fit_transform(data['Class'])
    
    return data, label_encoder.classes_

# Paths
train_dir = "C:/Users/jcman/Downloads/age_detection/faces/Train/"  # Update with your train directory path
train_csv = "C:/Users/jcman/Downloads/age_detection/faces/train.csv"  # Update with your CSV file path

# Load dataset
data, class_names = load_data(train_dir, train_csv)

# %%
# Part 3: Split the data into training and validation sets
train_data, val_data = train_test_split(data, test_size=0.2, stratify=data['label'], random_state=42)

# Check the split (optional)
print(f"Training data: {len(train_data)} samples")
print(f"Validation data: {len(val_data)} samples")
# Out:
# Training data: 15924 samples
# Validation data: 3982 samples

# %%
# Part 4: Create ImageDataGenerators for training and validation
train_datagen = ImageDataGenerator(rescale=1.0/255, 
                                   rotation_range=15, 
                                   width_shift_range=0.1, 
                                   height_shift_range=0.1, 
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1.0/255)

# Convert labels to string for sparse class_mode
train_data['label'] = train_data['label'].astype(str)
val_data['label'] = val_data['label'].astype(str)

# Create generators for training and validation
train_generator = train_datagen.flow_from_dataframe(
    train_data,
    x_col='path',
    y_col='label',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse'
)

val_generator = val_datagen.flow_from_dataframe(
    val_data,
    x_col='path',
    y_col='label',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse'
)
# Out:
# Found 15924 validated image filenames belonging to 3 classes.
# Found 3982 validated image filenames belonging to 3 classes.

# %%
# Part 5: Build the model using MobileNetV2 as the base
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)  # Add dropout for regularization
x = Dense(128, activation='relu')(x)
predictions = Dense(len(class_names), activation='softmax')(x)  # Output layer

model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the base model layers (fine-tuning the classifier)
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary (optional)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Set up callbacks
checkpoint = ModelCheckpoint(
    "age_model_weights.keras",  # Save the best model weights
    save_best_only=True,        # Only save when validation accuracy improves
    monitor='val_accuracy',     # Monitor validation accuracy
    mode='max',                 # Maximize validation accuracy
    verbose=1                   # Print updates when model is saved
)

early_stopping = EarlyStopping(
    monitor='val_loss',         # Monitor validation loss
    patience=5,                 # Stop training if no improvement for 5 epochs
    restore_best_weights=True   # Restore the best weights after stopping
)

# Train the model for 7 epochs
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=7,                  # Set the number of epochs to 7
    callbacks=[checkpoint, early_stopping],  # Add callbacks
    verbose=1                   # Print progress during training
)
# Out:
# Epoch 1/7
# C:\Users\jcman\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5657 - loss: 0.9981
# Epoch 1: val_accuracy improved from -inf to 0.62858, saving model to age_model_weights.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 877s 2s/step - accuracy: 0.5658 - loss: 0.9979 - val_accuracy: 0.6286 - val_loss: 0.8394
# Epoch 2/7
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.6195 - loss: 0.8251
# Epoch 2: val_accuracy improved from 0.62858 to 0.64515, saving model to age_model_weights.keras
# ...

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import os
import tensorflow as tf

# Define the path to the test directory
test_dir = r"C:\Users\jcman\Downloads\age_detection\faces_02\part3\images"

# Verify if the test directory exists
if not os.path.exists(test_dir):
    raise FileNotFoundError(f"The directory does not exist: {test_dir}")
else:
    print(f"Directory found: {test_dir}")

# Create a test dataset using image_dataset_from_directory
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',          # Labels are inferred from subfolder names
    label_mode='int',           # Match the sparse class mode
    image_size=(224, 224),      # Match the input size of the model
    batch_size=32,              # Batch size
    shuffle=False               # No shuffling for evaluation
)

# Normalize the test dataset
normalization_layer = tf.keras.layers.Rescaling(1./255)
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 9
#       7 # Verify if the test directory exists
#       8 if not os.path.exists(test_dir):
# ----> 9     raise FileNotFoundError(f"The directory does not exist: {test_dir}")
#      10 else:
#      11     print(f"Directory found: {test_dir}")
#
# FileNotFoundError: The directory does not exist: C:\Users\jcman\Downloads\age_detection\faces_02\part3\images
